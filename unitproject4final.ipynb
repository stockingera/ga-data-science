# %% [markdown]
# # Project 4
#
# In this project, you will summarize and present your analysis from Projects 1-3.

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer: This project serves to analyze the potential relationship between GPA, GRE and Prestige and graduate school admissions.

# %% [markdown]
# ### Dataset:  Write up a description of your data and any cleaning that was completed

# %% [markdown]
# Answer: In order to clean the data I pulled out any data points that were missing and excluded them from the data set used for analysis. I also measured to correlation between variables to ensure that my data set was a usable distribution. Following basic analysis I found that the data is close to normal with GPA and GRE slightly skewed to the upper ranges, meaning that although the data wasnt perfect, it provided a usable set for analysis.

# %% [markdown]
# ### Demo: Provide a table that explains the data by admission status

# %%
from __future__ import division
from scipy import stats
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline
df_raw = pd.read_csv("../assets/admissions.csv")
df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %%
df1=df_raw.describe()
df2=df_raw.std()
print df1



print df2
# Out:
#             admit         gre        gpa    prestige
# count  400.000000  398.000000  398.00000  399.000000
# mean     0.317500  588.040201    3.39093    2.486216
# std      0.466087  115.628513    0.38063    0.945333
# min      0.000000  220.000000    2.26000    1.000000
# 25%      0.000000  520.000000    3.13000    2.000000
# 50%      0.000000  580.000000    3.39500    2.000000
# 75%      1.000000  660.000000    3.67000    3.000000
# max      1.000000  800.000000    4.00000    4.000000
# admit         0.466087
# gre         115.628513
# gpa           0.380630
# prestige      0.945333
# dtype: float64

# %% [markdown]
# ### Methods: Write up the methods used in your analysis

# %% [markdown]
# Answer: To complete the analysis I used a logistic regression model. To do this I first made sure my data was clean and then I made sure there was no missing data. I then created dummy variables in order to train the algorithim. After training the data using dummy variables I preformed logit and then examined the odds ratios to determine if there was a relationship between prestige and admit or other factors. Using visualizations as well as analysis stratified by gpa and gre I was able to complete the analysis and begin to asses the present relationships.

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Answer: After completing the analysis of logit as well as examining the odds ratios, it can be said that the chances of being admitted to graduate school are 60% less for students who attended a 4th teir school than students who did not attend a 4th teir school. Furhtermore students who attend 4th tier schools odds of admission are 0.41 times the odds of students who did not attend a 4th teir school. Overall, for students with the same GPA's and GRE scores, students who attended a tier 4 undergraduate school had a 37% probablity of being admitted into grad school, while student who that attended a tier 1 school have a 73% chance of being admitted into grad school while other students do not. It can be stated based on this analysis that students that attend schools with higher prestiges have a better chance of being accepted into graduate school. However, more analysis would have to be done to concretely assume causation from this correlation.

# %% [markdown]
# ### Visuals: Provide a table or visualization of these results

# %%
from IPython.display import Image
Image('screenshot.png')

# %% [markdown]
# ### Discussion: Write up your discussion and future steps

# %% [markdown]
# Answer: Overall, this data did provide a strong indicator of a relationship between attending a school with higher prestige and gettting admitted into grad school. In oder to fully analyze this relationship it would be ideal to repeat the experiement on a different data set and then compare the results of the new data set to the original results. By repeating the experiment we can say with more certainty that the relationship exists within the greater population. Furthermore, it would be interesting to do an analysis that included for features such as gender, age of applicant or socioeconomic status.
